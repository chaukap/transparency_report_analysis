# %%
import pandas as pd
files = ! ls Raw_Data

# %%
dfs = [pd.read_excel("Raw_Data/" + file, engine='openpyxl') for file in files]
dfs[7].head()
# Out:
# /home/chaukap/.local/lib/python3.6/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#                 Law Enforcement Requests Report 2017  Unnamed: 1  \
# 0  Requests received for all Microsoft Services f...         NaN
# 1                                                NaN         NaN
# 2                                                NaN         NaN
# 3                                                NaN         NaN
# 4                                                NaN         NaN
#
#                                  Unnamed: 2  \
# 0                                       NaN
# 1                                       NaN
# 2                            Total Requests
# 3  Total Number of Law Enforcement Requests
# 4                                         #
#
#                                Unnamed: 3  Unnamed: 4  \
# 0                                     NaN         NaN
# ...

# %%
names = ["country", "total_requests", "total_requests_accounts", "year", "half"]

# %%
dfs[0].rename(columns={
    "Microsoft Services (Including Skype): July - December 2013 Law Enforcement Requests Report": "country",
    "Unnamed: 2": "total_requests",
    "Unnamed: 3": "total_requests_accounts"
}, inplace=True)
dfs[0]["year"] = 2013
dfs[0]["half"] = 2
dfs[0] = dfs[0][names][dfs[0].country == "United States"]
dfs[0]
# Out:
#           country total_requests total_requests_accounts  year  half
# 69  United States           5652                   12979  2013     2

# %%
dfs[1].rename(columns={
    "Law Enforcement Requests Report 2014": "country",
    "Unnamed: 2": "total_requests",
    "Unnamed: 3": "total_requests_accounts"
}, inplace=True)
dfs[1]["year"] = 2014
dfs[1]["half"] = 1
dfs[1] = dfs[1][names][dfs[1].country == "United States"]
dfs[1]
# Out:
#           country total_requests total_requests_accounts  year  half
# 72  United States           6919                   15730  2014     1

# %%
dfs[2].rename(columns={
    "Law Enforcement Requests Report 2014": "country",
    "Unnamed: 2": "total_requests",
    "Unnamed: 3": "total_requests_accounts"
}, inplace=True)
dfs[2]["year"] = 2014
dfs[2]["half"] = 2
dfs[2] = dfs[2][names][dfs[2].country == "United States"]
dfs[2]
# Out:
#           country total_requests total_requests_accounts  year  half
# 60  United States           5445                   13101  2014     2

# %%
dfs[3].rename(columns={
    "Law Enforcement Requests Report 2015": "country",
    "Unnamed: 2": "total_requests",
    "Unnamed: 3": "total_requests_accounts"
}, inplace=True)
dfs[3]["year"] = 2015
dfs[3]["half"] = 1
dfs[3] = dfs[3][names][dfs[3].country == "United States"]
dfs[3]
# Out:
#           country total_requests total_requests_accounts  year  half
# 68  United States           5940                   13570  2015     1

# %%
dfs[4].rename(columns={
    "Law Enforcement Requests Report 2015": "country",
    "Unnamed: 2": "total_requests",
    "Unnamed: 3": "total_requests_accounts"
}, inplace=True)
dfs[4]["year"] = 2015
dfs[4]["half"] = 2
dfs[4] = dfs[4][names][dfs[4].country == "United States"]
dfs[4]
# Out:
#           country total_requests total_requests_accounts  year  half
# 63  United States           5297                   12355  2015     2

# %%
dfs[5].rename(columns={
    "Law Enforcement Requests Report 2016": "country",
    "Unnamed: 2": "total_requests",
    "Unnamed: 3": "total_requests_accounts"
}, inplace=True)
dfs[5]["year"] = 2016
dfs[5]["half"] = 1
dfs[5] = dfs[5][names][dfs[5].country == "United States"]
dfs[5]
# Out:
#           country total_requests total_requests_accounts  year  half
# 67  United States           5168                   13755  2016     1

# %%
dfs[6].rename(columns={
    "Law Enforcement Requests Report 2016": "country",
    "Unnamed: 2": "total_requests",
    "Unnamed: 3": "total_requests_accounts"
}, inplace=True)
dfs[6]["year"] = 2016
dfs[6]["half"] = 2
dfs[6] = dfs[6][names][dfs[6].country == "United States"]
dfs[6]
# Out:
#           country total_requests total_requests_accounts  year  half
# 61  United States           4739                   10533  2016     2

# %%
dfs[7].rename(columns={
    "Law Enforcement Requests Report 2017": "country",
    "Unnamed: 2": "total_requests",
    "Unnamed: 3": "total_requests_accounts"
}, inplace=True)
dfs[7]["year"] = 2017
dfs[7]["half"] = 1
dfs[7] = dfs[7][names][dfs[7].country == "United States"]
dfs[7]
# Out:
#           country total_requests total_requests_accounts  year  half
# 64  United States           5401                   12936  2017     1

# %%
dfs[8].rename(columns={
    "Law Enforcement Requests Report 2017": "country",
    "Unnamed: 2": "total_requests",
    "Unnamed: 3": "total_requests_accounts"
}, inplace=True)
dfs[8]["year"] = 2017
dfs[8]["half"] = 2
dfs[8] = dfs[8][names][dfs[8].country == "United States"]
dfs[8]
# Out:
#           country total_requests total_requests_accounts  year  half
# 60  United States           3984                   10138  2017     2

# %%
dfs[9].rename(columns={
    "Law Enforcement Requests Report 2018": "country",
    "Unnamed: 3": "total_requests",
    "Unnamed: 4": "total_requests_accounts"
}, inplace=True)
dfs[9]["year"] = 2018
dfs[9]["half"] = 1
dfs[9] = dfs[9][names][dfs[9].country == "United States"]
dfs[9]
# Out:
#           country total_requests total_requests_accounts  year  half
# 55  United States           4948                   14015  2018     1

# %%
dfs[10].rename(columns={
    "Law Enforcement Requests Report 2018": "country",
    "Unnamed: 3": "total_requests",
    "Unnamed: 4": "total_requests_accounts"
}, inplace=True)
dfs[10]["year"] = 2018
dfs[10]["half"] = 2
dfs[10] = dfs[10][names][dfs[10].country == "United States"]
dfs[10]
# Out:
#           country total_requests total_requests_accounts  year  half
# 54  United States           4369                   11134  2018     2

# %%
dfs[11].rename(columns={
    "Law Enforcement Requests Report": "country",
    "Unnamed: 3": "total_requests",
    "Unnamed: 4": "total_requests_accounts"
}, inplace=True)
dfs[11]["year"] = 2019
dfs[11]["half"] = 1
dfs[11] = dfs[11][names][dfs[11].country == "United States"]
dfs[11]
# Out:
#           country total_requests total_requests_accounts  year  half
# 56  United States           4860                   14273  2019     1

# %%
dfs[12].rename(columns={
    "Law Enforcement Requests Report": "country",
    "Unnamed: 3": "total_requests",
    "Unnamed: 4": "total_requests_accounts"
}, inplace=True)
dfs[12]["year"] = 2019
dfs[12]["half"] = 2
dfs[12] = dfs[12][names][dfs[12].country == "United States"]
dfs[12]
# Out:
#           country total_requests total_requests_accounts  year  half
# 56  United States           4315                   12993  2019     2

# %%
dfs[13].rename(columns={
    "Law Enforcement Requests Report 2020": "country",
    "Unnamed: 3": "total_requests",
    "Unnamed: 4": "total_requests_accounts"
}, inplace=True)
dfs[13]["year"] = 2020
dfs[13]["half"] = 1
dfs[13] = dfs[13][names][dfs[13].country == "United States"]
dfs[13]
# Out:
#           country total_requests total_requests_accounts  year  half
# 52  United States           5507                   17717  2020     1

# %%
dfs[14].rename(columns={
    "Law Enforcement Requests Report 2020": "country",
    "Unnamed: 3": "total_requests",
    "Unnamed: 4": "total_requests_accounts"
}, inplace=True)
dfs[14]["year"] = 2020
dfs[14]["half"] = 2
dfs[14] = dfs[14][names][dfs[14].country == "United States"]
dfs[14]
# Out:
#           country total_requests total_requests_accounts  year  half
# 49  United States           5682                   16348  2020     2

# %%
dfs[15].rename(columns={
    "Law Enforcement Requests Report 2021": "country",
    "Unnamed: 3": "total_requests",
    "Unnamed: 4": "total_requests_accounts"
}, inplace=True)
dfs[15]["year"] = 2021
dfs[15]["half"] = 1
dfs[15] = dfs[15][names][dfs[15].country == "United States"]
dfs[15]
# Out:
#           country total_requests total_requests_accounts  year  half
# 52  United States           6392                   14195  2021     1

# %%
df = pd.concat(dfs)
df.head()
# Out:
#           country total_requests total_requests_accounts  year  half
# 69  United States           5652                   12979  2013     2
# 72  United States           6919                   15730  2014     1
# 60  United States           5445                   13101  2014     2
# 68  United States           5940                   13570  2015     1
# 63  United States           5297                   12355  2015     2

# %%
df.to_csv("../Clean_Data/Microsoft.csv")
