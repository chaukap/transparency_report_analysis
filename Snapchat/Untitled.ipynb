# %%
import pandas as pd

# %%
df = pd.read_csv("Raw_Data/Snapchat.csv")
df = df[["United States" in section for section in df.section]]

df
# Out:
#       period                                   section  \
# 0    2021-H1     United States Criminal Legal Requests
# 1    2021-H1     United States Criminal Legal Requests
# 2    2021-H1     United States Criminal Legal Requests
# 3    2021-H1     United States Criminal Legal Requests
# 4    2021-H1     United States Criminal Legal Requests
# 5    2021-H1     United States Criminal Legal Requests
# 6    2021-H1     United States Criminal Legal Requests
# 7    2021-H1     United States Criminal Legal Requests
# 8    2021-H1     United States Criminal Legal Requests
# 9    2021-H1     United States Criminal Legal Requests
# 10   2021-H1     United States Criminal Legal Requests
# 11   2021-H1     United States Criminal Legal Requests
# 12   2021-H1     United States Criminal Legal Requests
# 13   2021-H1     United States Criminal Legal Requests
# 14   2021-H1     United States Criminal Legal Requests
# 15   2021-H1     United States Criminal Legal Requests
# ...

# %%
df.groupby(["period", "metric"]).describe()
# Out:
#                                                            section         \
#                                                              count unique
# period  metric
# 2021-H1 account_identifiers                                      7      2
#         percentage_of_requests_where_some_data_was_prod...       6      1
#         requests                                                 7      2
#
#                                                                                                    \
#                                                                                               top
# period  metric
# 2021-H1 account_identifiers                                 United States Criminal Legal Requests
#         percentage_of_requests_where_some_data_was_prod...  United States Criminal Legal Requests
#         requests                                            United States Criminal Legal Requests
#
# ...
